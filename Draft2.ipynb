# %% [markdown]
# # Further model optimization by feature engineering
#
# # Using a better training algorithm like XGBoost and LGB

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
train_df = pd.read_csv('train.csv')

# %%
train_df.head(10)
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
# 5  1325467d  0848ef14a8dc6892  2019-09-06T17:55:06.279Z
# 6  1325467d  0848ef14a8dc6892  2019-09-06T17:55:06.913Z
# 7  1325467d  0848ef14a8dc6892  2019-09-06T17:55:07.546Z
# 8  1325467d  0848ef14a8dc6892  2019-09-06T17:55:07.979Z
# 9  1325467d  0848ef14a8dc6892  2019-09-06T17:55:08.566Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# ...

# %%
train_df['event_data'].iloc[10]
# Out:
# '{"coordinates":{"x":807,"y":619,"stage_width":1015,"stage_height":762},"event_count":9,"game_time":12672,"event_code":4070}'

# %%
train_asses = train_df[train_df['type'] == 'Assessment']

# %%
train_asses.head()
# Out:
#       event_id      game_session                 timestamp  \
# 2185  3bfd1a65  901acc108f55a5a1  2019-08-06T05:22:01.344Z
# 2186  db02c830  901acc108f55a5a1  2019-08-06T05:22:01.400Z
# 2187  a1e4395d  901acc108f55a5a1  2019-08-06T05:22:01.403Z
# 2188  a52b92d5  901acc108f55a5a1  2019-08-06T05:22:05.242Z
# 2189  a1e4395d  901acc108f55a5a1  2019-08-06T05:22:05.244Z
#
#                                              event_data installation_id  \
# 2185  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 2186  {"event_count":2,"game_time":37,"event_code":2...        0006a69f
# 2187  {"description":"Pull three mushrooms out of th...        0006a69f
# 2188  {"description":"Pull three mushrooms out of th...        0006a69f
# 2189  {"description":"To pick a mushroom, pull it ou...        0006a69f
#
#       event_count  event_code  game_time                         title  \
# 2185            1        2000          0  Mushroom Sorter (Assessment)
# ...

# %%
train_session = train_asses.groupby('game_session').max()

# %%
train_session.head()
# Out:
#                   event_id                 timestamp  \
# game_session
# 00097cda27afb726  fbaf3456  2019-09-15T16:37:09.223Z
# 000f68cff32664ef  ea296733  2019-10-12T23:09:24.134Z
# 0014403daadf67aa  f6947f54  2019-08-03T22:22:31.430Z
# 0014daa1d3e26eb2  fbaf3456  2019-09-24T22:29:41.496Z
# 0018a3df8beb755e  7ad3efc6  2019-10-02T18:04:49.509Z
#
#                                                          event_data  \
# game_session
# 00097cda27afb726  {"version":"1.0","event_count":1,"game_time":0...
# 000f68cff32664ef  {"weight":3,"pillars":[],"coordinates":{"x":87...
# 0014403daadf67aa  {"version":"1.0","event_count":1,"game_time":0...
# 0014daa1d3e26eb2  {"version":"1.0","event_count":1,"game_time":0...
# 0018a3df8beb755e  {"version":"1.0","event_count":1,"game_time":0...
#
#                  installation_id  event_count  event_code  game_time  \
# game_session
# 00097cda27afb726        01bdd720           36        4100      27810
# ...

# %%
event_codes = train_session['event_code'].unique()

# %%
for code in event_codes:
    x = train_asses[train_asses['event_code'] == code]['title'].unique()
    print(code, x)
    #if len(x) == 1: print(code, x)
# Out:
# 4100 ['Mushroom Sorter (Assessment)' 'Bird Measurer (Assessment)'
#  'Cauldron Filler (Assessment)' 'Cart Balancer (Assessment)'
#  'Chest Sorter (Assessment)']
# 4110 ['Bird Measurer (Assessment)']
# 3010 ['Mushroom Sorter (Assessment)' 'Bird Measurer (Assessment)'
#  'Cauldron Filler (Assessment)' 'Cart Balancer (Assessment)'
#  'Chest Sorter (Assessment)']
# 4070 ['Mushroom Sorter (Assessment)' 'Bird Measurer (Assessment)'
#  'Cauldron Filler (Assessment)' 'Chest Sorter (Assessment)'
#  'Cart Balancer (Assessment)']
# 3110 ['Mushroom Sorter (Assessment)' 'Bird Measurer (Assessment)'
#  'Cauldron Filler (Assessment)' 'Cart Balancer (Assessment)'
#  'Chest Sorter (Assessment)']
# 4090 ['Bird Measurer (Assessment)' 'Chest Sorter (Assessment)'
#  'Cart Balancer (Assessment)' 'Mushroom Sorter (Assessment)'
#  'Cauldron Filler (Assessment)']
# 2000 ['Mushroom Sorter (Assessment)' 'Bird Measurer (Assessment)'
#  'Cauldron Filler (Assessment)' 'Cart Balancer (Assessment)'
# ...

# %%
#for code in event_codes:
#x = train_asses[train_asses['event_code'] == 4070]['event_data'].unique()
#print(code, x)
    #if len(x) == 1: print(code, x)

# %%
event_df = pd.read_csv('specs.csv')

# %%
event_df.head()
# Out:
#    event_id                                               info  \
# 0  2b9272f4  The end of system-initiated feedback (Correct)...
# 1  df4fe8b6  The end of system-initiated feedback (Incorrec...
# 2  3babcb9b  The end of system-initiated instruction event ...
# 3  7f0836bf  The end of system-initiated instruction event ...
# 4  ab3136ba  The end of system-initiated instruction event ...
#
#                                                 args
# 0  [{"name":"game_time","type":"int","info":"mill...
# 1  [{"name":"game_time","type":"int","info":"mill...
# 2  [{"name":"game_time","type":"int","info":"mill...
# 3  [{"name":"game_time","type":"int","info":"mill...
# 4  [{"name":"game_time","type":"int","info":"mill...

# %%
event_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386 entries, 0 to 385
# Data columns (total 3 columns):
# event_id    386 non-null object
# info        386 non-null object
# args        386 non-null object
# dtypes: object(3)
# memory usage: 9.1+ KB

# %%
#event_df['info'].unique()

# %%
train_event_df = pd.merge(train_df, event_df, on='event_id', how='outer')

# %%
train_ev
